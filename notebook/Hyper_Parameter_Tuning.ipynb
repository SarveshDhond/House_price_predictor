# %% [markdown]
# # ANALYSIS
#
# #### IN THE PREVIOUS NOTEBOOK, WE IDENTIFIED TENSORFLOW AND XGBREGRESSOR AS THE TOP CANDIDATE MODELS.
#
# | ASPECT | TENSORFLOW | XGBREGRESSOR |
# | ---- | ---- | ---- |
# | Accuracy and MAE | 	Good performance, but higher MAE compared to XGBRegressor |	Best performance with higher accuracy and the lowest MAE |
# | Efficiency and Resources |	Slower training and more resource-intensive	|Faster training and more computationally efficient |
# | Best Use Case |	Suitable when deep learning experimentation is required |	Ideal when high performance, efficiency, and reliability are priorities |
#
#
# #### NEXT STEPS
# - Perform hyperparameter tuning on the XGBRegressor
# - Re-evaluate performance against the TensorFlow model
# - Select the best-performing model for final deployment

# %% [markdown]
# # IMPORT DATA

# %%
from google.colab import drive
drive.mount('/content/Drive')
# Out:
# Mounted at /content/Drive

# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv('/content/Drive/MyDrive/House_price_predictor/dataset/featured_data/featured_train_data.csv')
test_df = pd.read_csv('/content/Drive/MyDrive/House_price_predictor/dataset/featured_data/featured_test_data.csv')

# %%
X_train = train_df.drop(columns=['price'])
y_train = train_df['price']

X_test = test_df.drop(columns=['price'])
y_test = test_df['price']

# %% [markdown]
# # HYPERPARAMETER TUNING WITH OPTUNA

# %%
# !pip install optuna
import optuna
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
# Out:
# Collecting optuna
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.45)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.3.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 13.0 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.6.0

# %% [markdown]
# ## WITHOUT USING LOG VALUES

# %%
def objective(trial):

  # PARAMETER
  n_estimators = trial.suggest_int('n_estimators', 100 , 1000)
  max_depth = trial.suggest_int('max_depth', 1, 10)
  learning_rate = trial.suggest_float('learning_rate', 0.001, 0.3)
  eta = trial.suggest_float('eta', 0.1 , 0.5)
  subsample = trial.suggest_int('subsample', 0 , 1)
  random_state = 42


  # MODEL

  model = XGBRegressor(
      n_estimators=n_estimators,
      max_depth=max_depth,
      learning_rate=learning_rate,
      eta=eta,
      subsample=subsample,
      random_state=random_state
  )

  # TRAIN

  model.fit(X_train , y_train, verbose=False)

  y_pred = model.predict(X_test)

  mae = mean_absolute_error(y_test , y_pred)

  return mae


study = optuna.create_study(direction='minimize')
study.optimize(objective , n_trials=50)

print(study.best_params)
# Out:
# [I 2026-01-06 18:09:29,813] A new study created in memory with name: no-name-ab0a44a4-fa83-46dc-8d19-cddb1f9e9510
# [I 2026-01-06 18:09:34,350] Trial 0 finished with value: 239635.89824424568 and parameters: {'n_estimators': 114, 'max_depth': 3, 'learning_rate': 0.028553996703346428, 'eta': 0.3873972160771826, 'subsample': 0}. Best is trial 0 with value: 239635.89824424568.
# [I 2026-01-06 18:09:57,337] Trial 1 finished with value: 239635.89824424568 and parameters: {'n_estimators': 963, 'max_depth': 2, 'learning_rate': 0.14919098382603144, 'eta': 0.20469934653115282, 'subsample': 0}. Best is trial 0 with value: 239635.89824424568.
# [I 2026-01-06 18:10:03,543] Trial 2 finished with value: 239635.89824424568 and parameters: {'n_estimators': 243, 'max_depth': 9, 'learning_rate': 0.18930580772405017, 'eta': 0.31221896619262623, 'subsample': 0}. Best is trial 0 with value: 239635.89824424568.
 'subsample': 1}. Best is trial 15 with value: 40059.55462612282.
# [I 2026-01-06 18:26:03,707] Trial 35 finished with value: 239635.89824424568 and parameters: {'n_estimators': 111, 'max_depth': 4, 'learning_rate': 0.021001379545089967, 'eta': 0.4386872975839383, 'subsample': 0}. Best is trial 15 with value: 40059.55462612282.
# [I 2026-01-06 18:26:20,873] Trial 36 finished with value: 44265.92903371116 and parameters: {'n_estimators': 598, 'max_depth': 2, 'learning_rate': 0.15394648522961157, 'eta': 0.46995075457453483, 'subsample': 1}. Best is trial 15 with value: 40059.55462612282.
# [I 2026-01-06 18:26:49,725] Trial 37 finished with value: 42202.068625772765 and parameters: {'n_estimators': 646, 'max_depth': 5, 'learning_rate': 0.22239822199260598, 'eta': 0.3831774275468838, 'subsample': 1}. Best is trial 15 with value: 40059.55462612282.
# [I 2026-01-06 18:27:32,515] Trial 38 finished with value: 40489.134604122664 and parameters: {'n_estimators': 493, 'max_depth': 8, 'learning_rate': 0.04670815698445281, 'eta': 0.29091523215456694, 'subsample': 1}. Best is trial 15 with value: 40059.55462612282.
# [I 2026-01-06 18:27:57,798] Trial 39 finished with value: 42959.04311673925 and parameters: {'n_estimators': 569, 'max_depth': 4, 'learning_rate': 0.011657459907432128, 'eta': 0.3418277946900494, 'subsample': 1}. Best is trial 15 with value: 40059.55462612282.
# [I 2026-01-06 18:28:20,446] Trial 40 finished with value: 239635.89824424568 and parameters: {'n_estimators': 939, 'max_depth': 6, 'learning_rate': 0.10392766457686703, 'eta': 0.18992008826896256, 'subsample': 0}. Best is trial 15 with value: 40059.55462612282.
# [I 2026-01-06 18:28:54,483] Trial 41 finished with value: 40318.31247562356 and parameters: {'n_estimators': 736, 'max_depth': 5, 'learning_rate': 0.03039331350017835, 'eta': 0.47309554732340314, 'subsample': 1}. Best is trial 15 with value: 40059.55462612282.
# [I 2026-01-06 18:29:30,392] Trial 42 finished with value: 40223.3119400295 and parameters: {'n_estimators': 767, 'max_depth': 5, 'learning_rate': 0.03782788945767135, 'eta': 0.4829790667363115, 'subsample': 1}. Best is trial 15 with value: 40059.55462612282.
# [I 2026-01-06 18:30:01,315] Trial 43 finished with value: 40249.35232817218 and parameters: {'n_estimators': 812, 'max_depth': 4, 'learning_rate': 0.07640319543436161, 'eta': 0.4490829057434241, 'subsample': 1}. Best is trial 15 with value: 40059.55462612282.
# [I 2026-01-06 18:30:32,464] Trial 44 finished with value: 40234.171038329216 and parameters: {'n_estimators': 789, 'max_depth': 4, 'learning_rate': 0.08275110654105831, 'eta': 0.4406111432788816, 'subsample': 1}. Best is trial 15 with value: 40059.55462612282.
# [I 2026-01-06 18:30:56,898] Trial 45 finished with value: 41228.64669425717 and parameters: {'n_estimators': 771, 'max_depth': 3, 'learning_rate': 0.05544935883952131, 'eta': 0.40855412042452627, 'subsample': 1}. Best is trial 15 with value: 40059.55462612282.
# [I 2026-01-06 18:31:21,789] Trial 46 finished with value: 43834.79668206661 and parameters: {'n_estimators': 898, 'max_depth': 2, 'learning_rate': 0.0966113952728288, 'eta': 0.4775867607287732, 'subsample': 1}. Best is trial 15 with value: 40059.55462612282.
# [I 2026-01-06 18:31:50,019] Trial 47 finished with value: 41104.50084404444 and parameters: {'n_estimators': 845, 'max_depth': 3, 'learning_rate': 0.046391337667050635, 'eta': 0.36244578636367364, 'subsample': 1}. Best is trial 15 with value: 40059.55462612282.
# [I 2026-01-06 18:32:01,062] Trial 48 finished with value: 40808.33498949505 and parameters: {'n_estimators': 239, 'max_depth': 4, 'learning_rate': 0.08605417285214659, 'eta': 0.423088772738114, 'subsample': 1}. Best is trial 15 with value: 40059.55462612282.
# [I 2026-01-06 18:32:44,963] Trial 49 finished with value: 42280.55935466942 and parameters: {'n_estimators': 659, 'max_depth': 7, 'learning_rate': 0.13200360639705194, 'eta': 0.4419825626404187, 'subsample': 1}. Best is trial 15 with value: 40059.55462612282.
# {'n_estimators': 777, 'max_depth': 4, 'learning_rate': 0.05020333377045197, 'eta': 0.3794940311797137, 'subsample': 1}

# %% [markdown]
# ## WITH LOG VALUES

# %%
def objective(trial):

  # PARAMETER
  n_estimators = trial.suggest_int('n_estimators', 100 , 1000)
  max_depth = trial.suggest_int('max_depth', 1, 10)
  learning_rate = trial.suggest_float('learning_rate', 0.001, 0.3)
  eta = trial.suggest_float('eta', 0.1 , 0.5)
  subsample = trial.suggest_int('subsample', 0 , 1)
  random_state = 42

  y_train_log = np.log1p(y_train)



  # MODEL

  model = XGBRegressor(
      n_estimators=n_estimators,
      max_depth=max_depth,
      learning_rate=learning_rate,
      eta=eta,
      subsample=subsample,
      random_state=random_state
  )

  # TRAIN

  model.fit(X_train , y_train_log, verbose=False)

  y_pred_log = model.predict(X_test)

  y_pred = np.expm1(y_pred_log)

  mae = mean_absolute_error(y_test , y_pred)

  return mae


study = optuna.create_study(direction='minimize')
study.optimize(objective , n_trials=50)

print(study.best_params)
log_best_param = study.best_params
# Out:
# [I 2026-01-06 18:56:02,309] A new study created in memory with name: no-name-d3fe6d1f-edac-4eb1-abe0-66fc430cc989
# [I 2026-01-06 18:56:23,487] Trial 0 finished with value: 267941.87659958634 and parameters: {'n_estimators': 756, 'max_depth': 8, 'learning_rate': 0.13858983855245058, 'eta': 0.4530423604658589, 'subsample': 0}. Best is trial 0 with value: 267941.87659958634.
# [I 2026-01-06 18:56:29,247] Trial 1 finished with value: 267941.87659958634 and parameters: {'n_estimators': 222, 'max_depth': 9, 'learning_rate': 0.03432715227819864, 'eta': 0.4809556076363297, 'subsample': 0}. Best is trial 0 with value: 267941.87659958634.
# [I 2026-01-06 18:56:42,347] Trial 2 finished with value: 267941.87659958634 and parameters: {'n_estimators': 518, 'max_depth': 3, 'learning_rate': 0.2352118170745256, 'eta': 0.28850696768078476, 'subsample': 0}. Best is trial 0 with value: 267941.87659958634.
# [I 2026-01-06 18:56:56,892] Trial 3 finished with value: 53348.03564297713 and parameters: {'n_estimators': 491, 'max_depth': 1, 'learning_rate': 0.03606080740507165, 'eta': 0.40803664793545436, 'subsample': 1}. Best is trial 3 with value: 53348.03564297713.
# [I 2026-01-06 18:58:01,715] Trial 4 finished with value: 40615.40011577297 and parameters: {'n_estimators': 702, 'max_depth': 8, 'learning_rate': 0.07460829755337132, 'eta': 0.13267538834563541, 'subsample': 1}. Best is trial 4 with value: 40615.40011577297.
# [I 2026-01-06 18:58:08,000] Trial 5 finished with value: 267941.87659958634 and parameters: {'n_estimators': 227, 'max_depth': 10, 'learning_rate': 0.168940859767307, 'eta': 0.35074068752489984, 'subsample': 0}. Best is trial 4 with value: 40615.40011577297.
# [I 2026-01-06 18:58:38,713] Trial 6 finished with value: 40693.31250467578 and parameters: {'n_estimators': 878, 'max_depth': 3, 'learning_rate': 0.1010118562267336, 'eta': 0.4861952097820763, 'subsample': 1}. Best is trial 4 with value: 40615.40011577297.
# [I 2026-01-06 18:58:52,883] Trial 7 finished with value: 43777.783076551 and parameters: {'n_estimators': 447, 'max_depth': 2, 'learning_rate': 0.15708746278662794, 'eta': 0.42640224800978754, 'subsample': 1}. Best is trial 4 with value: 40615.40011577297.
# [I 2026-01-06 18:59:12,629] Trial 8 finished with value: 267941.87659958634 and parameters: {'n_estimators': 863, 'max_depth': 9, 'learning_rate': 0.17899311539898152, 'eta': 0.23554244397122717, 'subsample': 0}. Best is trial 4 with value: 40615.40011577297.
# [I 2026-01-06
 'subsample': 1}. Best is trial 31 with value: 39573.614553450985.
# [I 2026-01-06 19:19:12,079] Trial 43 finished with value: 39871.57615375527 and parameters: {'n_estimators': 725, 'max_depth': 4, 'learning_rate': 0.06707891600073454, 'eta': 0.3705575987257226, 'subsample': 1}. Best is trial 31 with value: 39573.614553450985.
# [I 2026-01-06 19:19:43,201] Trial 44 finished with value: 41307.66495749642 and parameters: {'n_estimators': 659, 'max_depth': 5, 'learning_rate': 0.15573633772994128, 'eta': 0.42323162742173404, 'subsample': 1}. Best is trial 31 with value: 39573.614553450985.
# [I 2026-01-06 19:20:08,385] Trial 45 finished with value: 39895.50671174049 and parameters: {'n_estimators': 582, 'max_depth': 4, 'learning_rate': 0.09055258738052817, 'eta': 0.3877456361456258, 'subsample': 1}. Best is trial 31 with value: 39573.614553450985.
# [I 2026-01-06 19:20:39,757] Trial 46 finished with value: 40033.24009003257 and parameters: {'n_estimators': 520, 'max_depth': 6, 'learning_rate': 0.10716014701434376, 'eta': 0.46493715010412573, 'subsample': 1}. Best is trial 31 with value: 39573.614553450985.
# [I 2026-01-06 19:21:02,421] Trial 47 finished with value: 42177.02743006905 and parameters: {'n_estimators': 719, 'max_depth': 2, 'learning_rate': 0.07332680894583513, 'eta': 0.3339464284971967, 'subsample': 1}. Best is trial 31 with value: 39573.614553450985.
# [I 2026-01-06 19:21:35,334] Trial 48 finished with value: 40995.57459324466 and parameters: {'n_estimators': 600, 'max_depth': 5, 'learning_rate': 0.018763826521011766, 'eta': 0.4995182184391824, 'subsample': 1}. Best is trial 31 with value: 39573.614553450985.
# [I 2026-01-06 19:21:53,083] Trial 49 finished with value: 42330.51810931033 and parameters: {'n_estimators': 544, 'max_depth': 2, 'learning_rate': 0.060603206418026107, 'eta': 0.36220429455298253, 'subsample': 1}. Best is trial 31 with value: 39573.614553450985.
# {'n_estimators': 549, 'max_depth': 6, 'learning_rate': 0.05485753874997094, 'eta': 0.21400082394417877, 'subsample': 1}

# %% [markdown]
# # MODEL RETEST

# %%
without_log_params = {'n_estimators': 777, 'max_depth': 4, 'learning_rate': 0.05020333377045197, 'eta': 0.3794940311797137, 'subsample': 1}
log_params = {'n_estimators': 549, 'max_depth': 6, 'learning_rate': 0.05485753874997094, 'eta': 0.21400082394417877, 'subsample': 1}

# %%
from xgboost import XGBRegressor

Model_1 = XGBRegressor(**without_log_params)
Model_2 = XGBRegressor(**log_params)

# %%
# DATA
X_train = X_train.copy()
X_test = X_test.copy()
y_train = y_train.copy()
y_train_log = np.log1p(y_train)
y_test = y_test.copy()
y_test_log = np.log1p(y_test)

# %%
# MODEL 1 -> WITHOUT LOG

Model_1.fit(X_train , y_train , verbose=False)
y_pred_1 = Model_1.predict(X_test)
mae_1 = mean_absolute_error(y_test , y_pred_1)
print(f'Model 1 MAE: {mae_1}')

# MODEL 2 -> WITH LOG

Model_2.fit(X_train , y_train_log , verbose=False)
y_pred_log_2 = Model_2.predict(X_test)
y_pred_2 = np.log1p(y_pred_log_2)

mae_log = mean_absolute_error(y_test_log , y_pred_log_2)
mae_2 = mean_absolute_error(y_test , y_pred_2)

print(f'Model 2 MAE: {mae_2}')
print(f'Model 2 MAE: {mae_log}')
# Out:
# Model 1 MAE: 40059.55462612282
# Model 2 MAE: 492252.36775736965
# Model 2 MAE: 0.07635364291911705

# %% [markdown]
# # SAVING MODEL 1 AS IT PERFORMED THE BEST

# %%
import pickle

MODEL_PATH = '/content/Drive/MyDrive/House_price_predictor/XGB_FINAL.pkl'

with open(MODEL_PATH, 'wb') as file:
    pickle.dump(Model_1, file)
