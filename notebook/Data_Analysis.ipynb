# %% [markdown]
# # IMPORT RAW DATASET

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/Drive')

# %cd /content/Drive/MyDrive
# Out:
# Mounted at /content/Drive
# /content/Drive/MyDrive

# %%
df = pd.read_csv('/content/Drive/MyDrive/House_price_predictor/dataset/raw_data/house_raw.csv')
city_df = pd.read_csv('/content/Drive/MyDrive/House_price_predictor/dataset/raw_data/city_raw.csv')

# %% [markdown]
# # INITIAL DATA ANALYSIS

# %%
df.head()
# Out:
#          date  median_sale_price  median_list_price  median_ppsf  \
# 0  2012-03-31            46550.0           217450.0    31.813674
# 1  2012-04-30            61870.0           245000.0    40.723982
# 2  2012-05-31           125500.0           217450.0    63.913043
# 3  2012-06-30           153000.0           189900.0    81.598080
# 4  2012-07-31           165500.0           154000.0    81.598080
#
#    median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 0        110.183666        14.0           23.0          44.0       64.0
# 1        130.528256        22.0           29.0          56.0       69.0
# 2        119.919216        24.0           40.0          63.0       60.0
# 3        105.617353        34.0           46.0          50.0       57.0
# 4         83.921175        39.0           49.0          42.0       50.0
#
#    median_dom  ...  Total Housing Units  Median Rent  Median Home Value  \
# ...

# %%
df.shape
# Out:
# (884092, 39)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 884092 entries, 0 to 884091
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   date                          884092 non-null  object
#  1   median_sale_price             884092 non-null  float64
#  2   median_list_price             884092 non-null  float64
#  3   median_ppsf                   884092 non-null  float64
#  4   median_list_ppsf              884092 non-null  float64
#  5   homes_sold                    884092 non-null  float64
#  6   pending_sales                 884092 non-null  float64
#  7   new_listings                  884092 non-null  float64
#  8   inventory                     884092 non-null  float64
#  9   median_dom                    884092 non-null  float64
#  10  avg_sale_to_list              884092 non-null  float64
#  11  sold_above_list               884092 non-null  float64
# ...

# %% [markdown]
# # MAPPING CITY, LATITUDE & LONGITUDE

# %%
city_df.head()
# Out:
#         City  Latitude  Longitude
# 0    Atlanta     33.75     -84.39
# 1     Austin     30.27     -97.74
# 2     Boston     42.36     -71.06
# 3  Baltimore     39.29     -76.61
# 4    Chicago     41.88     -87.63

# %% [markdown]
# ## FUNCTION TO CLEAN CITY NAMES

# %%
def clean_text(x):
  x = x.lower()
  x = x.strip()
  x = x.split('-')[0]
  x = x.split('_')[0]
  x = x.replace('.','')
  x = x.replace('city','')
  return x

df['city_full'] = df['city_full'].apply(clean_text)
city_df['city_full'] = city_df['City'].apply(clean_text)
city_df.drop(columns=['City'], inplace=True)

# %% [markdown]
# ## MERGE 2 DATAFRAMES TO MAP CITY WITH LATITUDE AND LONGITUDE

# %%
df = pd.merge(df , city_df, on='city_full', how='left')

# %%
df.head()
# Out:
#          date  median_sale_price  median_list_price  median_ppsf  \
# 0  2012-03-31            46550.0           217450.0    31.813674
# 1  2012-04-30            61870.0           245000.0    40.723982
# 2  2012-05-31           125500.0           217450.0    63.913043
# 3  2012-06-30           153000.0           189900.0    81.598080
# 4  2012-07-31           165500.0           154000.0    81.598080
#
#    median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 0        110.183666        14.0           23.0          44.0       64.0
# 1        130.528256        22.0           29.0          56.0       69.0
# 2        119.919216        24.0           40.0          63.0       60.0
# 3        105.617353        34.0           46.0          50.0       57.0
# 4         83.921175        39.0           49.0          42.0       50.0
#
#    median_dom  ...  Median Home Value  Total Labor Force  \
# 0        59.5  ...           279500.0             3171.0
# ...

# %%
df.isnull().sum()
# Out:
# date                            0
# median_sale_price               0
# median_list_price               0
# median_ppsf                     0
# median_list_ppsf                0
# homes_sold                      0
# pending_sales                   0
# new_listings                    0
# inventory                       0
# median_dom                      0
# avg_sale_to_list                0
# sold_above_list                 0
# off_market_in_two_weeks         0
# city                            0
# zipcode                         0
# year                            0
# bank                            0
# bus                             0
# hospital                        0
# mall                            0
# park                            0
# restaurant                      0
# school                          0
# station                         0
# supermarket                     0
# Total Population                0
# Median Age                      0
# ...

# %% [markdown]
# # DROPPING DUPLICATED ROWS

# %%
df[df.duplicated()].shape[0]
# Out:
# 0

# %%
df[df.drop(columns=['date']).duplicated()].shape[0]
# Out:
# 7363

# %%
df = df.drop_duplicates(subset=df.drop(columns=['date']))

# %% [markdown]
# # ADJUST COLUMN NAMES

# %%
df.columns
# Out:
# Index(['date', 'median_sale_price', 'median_list_price', 'median_ppsf',
#        'median_list_ppsf', 'homes_sold', 'pending_sales', 'new_listings',
#        'inventory', 'median_dom', 'avg_sale_to_list', 'sold_above_list',
#        'off_market_in_two_weeks', 'city', 'zipcode', 'year', 'bank', 'bus',
#        'hospital', 'mall', 'park', 'restaurant', 'school', 'station',
#        'supermarket', 'Total Population', 'Median Age', 'Per Capita Income',
#        'Total Families Below Poverty', 'Total Housing Units', 'Median Rent',
#        'Median Home Value', 'Total Labor Force', 'Unemployed Population',
#        'Total School Age Population', 'Total School Enrollment',
#        'Median Commute Time', 'price', 'city_full', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.columns=['date', 'median_sale_price', 'median_list_price', 'median_ppsf',
       'median_list_ppsf', 'homes_sold', 'pending_sales', 'new_listings',
       'inventory', 'median_dom', 'avg_sale_to_list', 'sold_above_list',
       'off_market_in_two_weeks', 'city', 'zipcode', 'year', 'bank', 'bus',
       'hospital', 'mall', 'park', 'restaurant', 'school', 'station',
       'supermarket', 'Total_Population', 'Median_Age', 'Per_Capita_Income',
       'Total_Families_Below_Poverty', 'Total_Housing_Units', 'Median_Rent',
       'Median_Home_Value', 'Total_Labor_Force', 'Unemployed_Population',
       'Total_School_Age_Population', 'Total_School_Enrollment',
       'Median_Commute_Time', 'price', 'city_full', 'Latitude', 'Longitude']

# %% [markdown]
# # SEPERATE YEAR / MONTH AND QUARTER FROM DATE

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['quarter'] = df['date'].dt.quarter

# %%
df.drop(columns=['date'], inplace=True)

# %%
df['year'].sort_values().unique()
# Out:
# array([2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
#        2023], dtype=int32)

# %% [markdown]
# ## SPLIT DATA INTO TRAIN & TEST BASED ON YEAR

# %%
train_df = df[df['year'] < 2020]
test_df = df[df['year'] >= 2020]

# %%
df.columns
# Out:
# Index(['median_sale_price', 'median_list_price', 'median_ppsf',
#        'median_list_ppsf', 'homes_sold', 'pending_sales', 'new_listings',
#        'inventory', 'median_dom', 'avg_sale_to_list', 'sold_above_list',
#        'off_market_in_two_weeks', 'city', 'zipcode', 'year', 'bank', 'bus',
#        'hospital', 'mall', 'park', 'restaurant', 'school', 'station',
#        'supermarket', 'Total_Population', 'Median_Age', 'Per_Capita_Income',
#        'Total_Families_Below_Poverty', 'Total_Housing_Units', 'Median_Rent',
#        'Median_Home_Value', 'Total_Labor_Force', 'Unemployed_Population',
#        'Total_School_Age_Population', 'Total_School_Enrollment',
#        'Median_Commute_Time', 'price', 'city_full', 'Latitude', 'Longitude',
#        'month', 'quarter'],
#       dtype='object')

# %% [markdown]
# # SAVE TRAIN & TEST DATASET

# %%
train_df.to_csv('/content/Drive/MyDrive/House_price_predictor/dataset/processed_data/processed_train_data.csv', index=False)
test_df.to_csv('/content/Drive/MyDrive/House_price_predictor/dataset/processed_data/processed_test_data.csv', index=False)
